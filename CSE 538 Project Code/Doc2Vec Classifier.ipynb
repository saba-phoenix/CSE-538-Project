# %%
import logging
import random

import numpy as np
import pandas as pd

from gensim.models import doc2vec
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
def read_dataset(path):
    dataset = pd.read_csv(path, header=0, delimiter="\t")
    x_train, x_test, y_train, y_test = train_test_split(dataset.review, dataset.sentiment, random_state=0, test_size=0.1)
    x_train = label_sentences(x_train, 'Train')
    x_test = label_sentences(x_test, 'Test')
    all_data = x_train + x_test
    return x_train, x_test, y_train, y_test, all_data

# %%
def read_dataset_df(df):
    dataset = df
    x_train, x_test, y_train, y_test = train_test_split(dataset.data, dataset.outcome, random_state=0, test_size=0.3)
    x_train = label_sentences(x_train, 'Train')
    x_test = label_sentences(x_test, 'Test')
    all_data = x_train + x_test
    return x_train, x_test, y_train, y_test, all_data

# %%
def label_sentences(corpus, label_type):
    """
    Gensim's Doc2Vec implementation requires each document/paragraph to have a label associated with it.
    We do this by using the LabeledSentence method. The format will be "TRAIN_i" or "TEST_i" where "i" is
    a dummy index of the review.
    """
    labeled = []
    for i, v in enumerate(corpus):
        label = label_type + '_' + str(i)
        labeled.append(doc2vec.LabeledSentence(v.split(), [label]))
    return labeled

# %%
def get_vectors(doc2vec_model, corpus_size, vectors_size, vectors_type):
    """
    Get vectors from trained doc2vec model
    :param doc2vec_model: Trained Doc2Vec model
    :param corpus_size: Size of the data
    :param vectors_size: Size of the embedding vectors
    :param vectors_type: Training or Testing vectors
    :return: list of vectors
    """
    vectors = np.zeros((corpus_size, vectors_size))
    for i in range(0, corpus_size):
        prefix = vectors_type + '_' + str(i)
        vectors[i] = doc2vec_model.docvecs[prefix]
    return vectors

# %%
def train_doc2vec(corpus):
    logging.info("Building Doc2Vec vocabulary")
    d2v = doc2vec.Doc2Vec(min_count=1,  # Ignores all words with total frequency lower than this
                          window=10,  # The maximum distance between the current and predicted word within a sentence
                          vector_size=300,  # Dimensionality of the generated feature vectors
                          workers=5,  # Number of worker threads to train the model
                          alpha=0.025,  # The initial learning rate
                          min_alpha=0.00025,  # Learning rate will linearly drop to min_alpha as training progresses
                          dm=0, # dm defines the training algorithm. If dm=1 means ‘distributed memory’ (PV-DM)
                                 # and dm =0 means ‘distributed bag of words’ (PV-DBOW)
                          dbow_words  = 1,
                          dm_mean = 1)  
    d2v.build_vocab(corpus)

    logging.info("Training Doc2Vec model")
    # 10 epochs take around 10 minutes on my machine (i7), if you have more time/computational power make it 20
    for epoch in range(10):
        logging.info('Training iteration #{0}'.format(epoch))
        d2v.train(corpus, total_examples=d2v.corpus_count, epochs=d2v.iter)
        # shuffle the corpus
        random.shuffle(corpus)
        # decrease the learning rate
        d2v.alpha -= 0.0002
        # fix the learning rate, no decay
        d2v.min_alpha = d2v.alpha

    logging.info("Saving trained Doc2Vec model")
    d2v.save("d2v.model")
    return d2v

# %%
def train_classifier(d2v, training_vectors, training_labels):
    logging.info("Classifier training")
    train_vectors = get_vectors(d2v, len(training_vectors), 300, 'Train')
    model = LinearSVC(penalty='l2')
    model.fit(train_vectors, np.array(training_labels))
    training_predictions = model.predict(train_vectors)
    logging.info('Training predicted classes: {}'.format(np.unique(training_predictions)))
    logging.info('Training accuracy: {}'.format(accuracy_score(training_labels, training_predictions)))
    logging.info('Training F1 score: {}'.format(f1_score(training_labels, training_predictions, average='weighted')))
    return model

# %%
def test_classifier(d2v, classifier, testing_vectors, testing_labels):
    logging.info("Classifier testing")
    test_vectors = get_vectors(d2v, len(testing_vectors), 300, 'Test')
    testing_predictions = classifier.predict(test_vectors)
    logging.info('Testing predicted classes: {}'.format(np.unique(testing_predictions)))
    logging.info('Testing accuracy: {}'.format(accuracy_score(testing_labels, testing_predictions)))
    logging.info('Testing F1 score: {}'.format(f1_score(testing_labels, testing_predictions, average='weighted')))

# %%
import os
import pandas as pd
from collections import Counter

PATH = '..\\Emotion Flow GitHub\\data_all\\'

data = []

for root, dirs, files in os.walk(PATH):
    for i,name in enumerate(files):
        if name.endswith((".txt")):
            dir_split = root.replace('.','')
            dir_split = dir_split.split('\\')
            category = dir_split[3]
            outcome = dir_split[4]
            file = open(root+'\\'+name, 'r', encoding='utf-8',errors='ignore')
            text_data = file.read()
            temp = []
            temp.append(category)
            temp.append(text_data)
            temp.append(outcome)
            data.append(temp)
            
            #print(category,outcome,name)
file.close()

# %%
df = pd.DataFrame(data)
df.columns = ['category','data','outcome']
print(len(df))
#df['value']=df.outcome.str[7:8]
df['outcome']=df.outcome.str[0:7]
print(df.head())
# Out:
# 1003
#             category                                               data  \
# 0  Detective_Mystery  \n\nE-text prepared by Juliet Sutherland, Mary...
# 1  Detective_Mystery  PINES***\n\n\nE-text prepared by Juliet Suther...
# 2  Detective_Mystery  \n\n\n\nProduced by Juliet Sutherland, Mary Me...
# 3  Detective_Mystery  \n\nE-text prepared by Juliet Sutherland, Mary...
# 4  Detective_Mystery  \n\n\n\nProduced by Steven desJardins and PG D...
#
#    outcome
# 0  failure
# 1  failure
# 2  failure
# 3  failure
# 4  failure

# %%
if __name__ == "__main__":
    x_train, x_test, y_train, y_test, all_data = read_dataset_df(df)
    d2v_model = train_doc2vec(all_data)
    classifier = train_classifier(d2v_model, x_train, y_train)
    test_classifier(d2v_model, classifier, x_test, y_test)
# Out:
# C:\Users\Prime\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `LabeledSentence` (Class will be removed in 4.0.0, use TaggedDocument instead).
#   # Remove the CWD from sys.path while we load stuff.
# 2018-11-20 18:02:40,376 : INFO : Building Doc2Vec vocabulary
# 2018-11-20 18:02:40,376 : INFO : collecting all words and their counts
# 2018-11-20 18:02:40,376 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-11-20 18:02:42,922 : INFO : collected 511920 word types and 1003 unique tags from a corpus of 1003 examples and 13654253 words
# 2018-11-20 18:02:42,922 : INFO : Loading a fresh vocabulary
# 2018-11-20 18:02:44,075 : INFO : min_count=1 retains 511920 unique words (100% of original 511920, drops 0)
# 2018-11-20 18:02:44,076 : INFO : min_count=1 leaves 13654253 word corpus (100% of original 13654253, drops 0)
# 2018-11-20 18:02:45,205 : INFO : deleting the raw counts dictionary of 511920 items
# 2018-11-20 18:02:45,220 : INFO : sample=0.001 downsamples 39 most-common words
# 2018-11-20 18:02:45,220 : INFO : downsampling leaves estimated 10877305 word corpus (79.7% of prior 13654253)
# 2018-11-20 18:02:46,375 : INFO : estimated required memory for 511920 words and 300 dimensions: 1485972200 bytes
# 2018-11-20 18:02:46,376 : INFO : resetting layer weights
# 2018-11-20 18:02:52,319 : INFO : Training Doc2Vec model
# 2018-11-20 18:02:52,319 : INFO : Training iteration #0
# C:\Users\Prime\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# 2018-11-20 18:02:52,319 : INFO : training model with 5 workers on 511920 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=10
# 2018-11-20 18:02:53,443 : INFO : EPOCH 1 - PROGRESS: at 1.60% examples, 105652 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:02:54,467 : INFO : EPOCH 1 - PROGRESS: at 3.29% examples, 124098 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:02:55,518 : INFO : EPOCH 1 - PROGRESS: at 4.99% examples, 129996 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:02:56,568 : INFO : EPOCH 1 - PROGRESS: at 6.88% examples, 133045 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:02:57,620 : INFO : EPOCH 1 - PROGRESS: at 8.67% examples, 134554 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:02:58,716 : INFO : EPOCH 1 - PROGRESS: at 10.47% examples, 135714 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:02:59,746 : INFO : EPOCH 1 - PROGRESS: at 11.96% examples, 136167 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:00,774 : INFO : EPOCH 1 - PROGRESS: at 13.76% examples, 137599 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:01,806 : INFO : EPOCH 1 - PROGRESS: at 15.35% examples, 137302 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:03:02,966 : INFO : EPOCH 1 - PROGRESS: at 17.25% examples, 137678 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:03:04,096 : INFO : EPOCH 1 - PROGRESS: at 19.14% examples, 138043 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:05,110 : INFO : EPOCH 1 - PROGRESS: at 20.94% examples, 138516 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:06,160 : INFO : EPOCH 1 - PROGRESS: at 22.73% examples, 138774 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:07,188 : INFO : EPOCH 1 - PROGRESS: at 24.43% examples, 139055 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:08,206 : INFO : EPOCH 1 - PROGRESS: at 26.32% examples, 138725 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:03:09,207 : INFO : EPOCH 1 - PROGRESS: at 28.02% examples, 139086 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:10,240 : INFO : EPOCH 1 - PROGRESS: at 29.81% examples, 139202 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:11,400 : INFO : EPOCH 1 - PROGRESS: at 31.90% examples, 139012 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:12,436 : INFO : EPOCH 1 - PROGRESS: at 33.90% examples, 139960 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:13,549 : INFO : EPOCH 1 - PROGRESS: at 35.59% examples, 139734 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:14,569 : INFO : EPOCH 1 - PROGRESS: at 37.39% examples, 139412 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:15,699 : INFO : EPOCH 1 - PROGRESS: at 38.98% examples, 138927 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:16,852 : INFO : EPOCH 1 - PROGRESS: at 40.58% examples, 137889 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:17,882 : INFO : EPOCH 1 - PROGRESS: at 42.57% examples, 137972 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:18,994 : INFO : EPOCH 1 - PROGRESS: at 44.67% examples, 138067 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:20,055 : INFO : EPOCH 1 - PROGRESS: at 46.56% examples, 138226 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:03:21,128 : INFO : EPOCH 1 - PROGRESS: at 48.16% examples, 138078 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:03:22,141 : INFO : EPOCH 1 - PROGRESS: at 49.75% examples, 138259 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:23,172 : INFO : EPOCH 1 - PROGRESS: at 51.45% examples, 138575 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:24,276 : INFO : EPOCH 1 - PROGRESS: at 53.14% examples, 138526 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:25,293 : INFO : EPOCH 1 - PROGRESS: at 54.84% examples, 138789 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:26,325 : INFO : EPOCH 1 - PROGRESS: at 56.53% examples, 138540 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:27,342 : INFO : EPOCH 1 - PROGRESS: at 58.52% examples, 138835 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:28,429 : INFO : EPOCH 1 - PROGRESS: at 60.42% examples, 138846 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:29,481 : INFO : EPOCH 1 - PROGRESS: at 62.11% examples, 138889 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:30,532 : INFO : EPOCH 1 - PROGRESS: at 63.91% examples, 138752 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:31,643 : INFO : EPOCH 1 - PROGRESS: at 66.00% examples, 138828 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:32,747 : INFO : EPOCH 1 - PROGRESS: at 68.10% examples, 138720 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:03:33,789 : INFO : EPOCH 1 - PROGRESS: at 69.79% examples, 138647 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:34,804 : INFO : EPOCH 1 - PROGRESS: at 71.49% examples, 138853 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:35,961 : INFO : EPOCH 1 - PROGRESS: at 73.18% examples, 138685 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:37,015 : INFO : EPOCH 1 - PROGRESS: at 74.98% examples, 138864 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:38,158 : INFO : EPOCH 1 - PROGRESS: at 76.67% examples, 138843 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:39,173 : INFO : EPOCH 1 - PROGRESS: at 78.36% examples, 139137 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:40,230 : INFO : EPOCH 1 - PROGRESS: at 80.26% examples, 138827 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:41,341 : INFO : EPOCH 1 - PROGRESS: at 82.15% examples, 138925 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:42,438 : INFO : EPOCH 1 - PROGRESS: at 83.95% examples, 138987 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:03:43,544 : INFO : EPOCH 1 - PROGRESS: at 85.74% examples, 139047 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:44,592 : INFO : EPOCH 1 - PROGRESS: at 87.64% examples, 139125 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:45,613 : INFO : EPOCH 1 - PROGRESS: at 89.43% examples, 139133 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:46,695 : INFO : EPOCH 1 - PROGRESS: at 91.13% examples, 138893 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:47,854 : INFO : EPOCH 1 - PROGRESS: at 92.92% examples, 138804 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:03:48,864 : INFO : EPOCH 1 - PROGRESS: at 94.62% examples, 138965 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:49,890 : INFO : EPOCH 1 - PROGRESS: at 96.81% examples, 138943 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:50,913 : INFO : EPOCH 1 - PROGRESS: at 98.80% examples, 139061 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:51,279 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-11-20 18:03:51,418 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-20 18:03:51,486 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-20 18:03:51,539 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-20 18:03:51,546 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-20 18:03:51,547 : INFO : EPOCH - 1 : training on 13654253 raw words (8238048 effective words) took 59.2s, 139124 effective words/s
# 2018-11-20 18:03:52,703 : INFO : EPOCH 2 - PROGRESS: at 1.60% examples, 103426 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:53,754 : INFO : EPOCH 2 - PROGRESS: at 3.19% examples, 116183 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:03:54,867 : INFO : EPOCH 2 - PROGRESS: at 4.89% examples, 122009 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:03:56,047 : INFO : EPOCH 2 - PROGRESS: at 6.88% examples, 124165 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:57,202 : INFO : EPOCH 2 - PROGRESS: at 8.67% examples, 126220 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:58,249 : INFO : EPOCH 2 - PROGRESS: at 10.47% examples, 129524 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:03:59,264 : INFO : EPOCH 2 - PROGRESS: at 11.86% examples, 129593 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:00,268 : INFO : EPOCH 2 - PROGRESS: at 13.46% examples, 130545 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:01,338 : INFO : EPOCH 2 - PROGRESS: at 15.15% examples, 130938 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:02,372 : INFO : EPOCH 2 - PROGRESS: at 16.65% examples, 130068 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:03,433 : INFO : EPOCH 2 - PROGRESS: at 18.25% examples, 131016 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:04,520 : INFO : EPOCH 2 - PROGRESS: at 19.84% examples, 129668 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:05,577 : INFO : EPOCH 2 - PROGRESS: at 21.44% examples, 128745 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:06,599 : INFO : EPOCH 2 - PROGRESS: at 22.73% examples, 127628 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:07,740 : INFO : EPOCH 2 - PROGRESS: at 24.53% examples, 128284 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:08,749 : INFO : EPOCH 2 - PROGRESS: at 26.52% examples, 129098 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:09,777 : INFO : EPOCH 2 - PROGRESS: at 27.92% examples, 128310 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:10,874 : INFO : EPOCH 2 - PROGRESS: at 29.71% examples, 128508 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:11,896 : INFO : EPOCH 2 - PROGRESS: at 31.21% examples, 128572 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:12,888 : INFO : EPOCH 2 - PROGRESS: at 32.90% examples, 128465 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:14,203 : INFO : EPOCH 2 - PROGRESS: at 34.60% examples, 126951 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:15,269 : INFO : EPOCH 2 - PROGRESS: at 36.29% examples, 127454 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:16,313 : INFO : EPOCH 2 - PROGRESS: at 37.79% examples, 126865 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:17,345 : INFO : EPOCH 2 - PROGRESS: at 38.98% examples, 125877 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:18,438 : INFO : EPOCH 2 - PROGRESS: at 40.58% examples, 125727 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:19,485 : INFO : EPOCH 2 - PROGRESS: at 42.47% examples, 125847 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:20,515 : INFO : EPOCH 2 - PROGRESS: at 44.57% examples, 126748 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:21,539 : INFO : EPOCH 2 - PROGRESS: at 46.26% examples, 126764 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:22,540 : INFO : EPOCH 2 - PROGRESS: at 47.66% examples, 126887 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:23,634 : INFO : EPOCH 2 - PROGRESS: at 49.15% examples, 126793 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:24,635 : INFO : EPOCH 2 - PROGRESS: at 50.75% examples, 127093 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:25,653 : INFO : EPOCH 2 - PROGRESS: at 52.04% examples, 126876 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:26,668 : INFO : EPOCH 2 - PROGRESS: at 53.54% examples, 127049 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:27,854 : INFO : EPOCH 2 - PROGRESS: at 55.13% examples, 126696 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:29,008 : INFO : EPOCH 2 - PROGRESS: at 56.93% examples, 126749 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:30,041 : INFO : EPOCH 2 - PROGRESS: at 58.82% examples, 126882 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:31,132 : INFO : EPOCH 2 - PROGRESS: at 60.52% examples, 126899 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:32,279 : INFO : EPOCH 2 - PROGRESS: at 62.21% examples, 126951 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:33,288 : INFO : EPOCH 2 - PROGRESS: at 64.11% examples, 127419 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:34,342 : INFO : EPOCH 2 - PROGRESS: at 65.90% examples, 127359 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:35,354 : INFO : EPOCH 2 - PROGRESS: at 68.00% examples, 127740 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:36,354 : INFO : EPOCH 2 - PROGRESS: at 69.29% examples, 127307 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:37,435 : INFO : EPOCH 2 - PROGRESS: at 70.99% examples, 127453 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:38,538 : INFO : EPOCH 2 - PROGRESS: at 72.08% examples, 126621 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:39,669 : INFO : EPOCH 2 - PROGRESS: at 73.98% examples, 127012 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:40,770 : INFO : EPOCH 2 - PROGRESS: at 75.57% examples, 127259 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:41,864 : INFO : EPOCH 2 - PROGRESS: at 77.17% examples, 127407 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:42,937 : INFO : EPOCH 2 - PROGRESS: at 78.86% examples, 127667 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:43,925 : INFO : EPOCH 2 - PROGRESS: at 80.96% examples, 127956 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:44,931 : INFO : EPOCH 2 - PROGRESS: at 82.55% examples, 128241 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:46,019 : INFO : EPOCH 2 - PROGRESS: at 84.15% examples, 128222 words/s, in_qsize 10, out_qsize 1
# 2018-11-20 18:04:47,030 : INFO : EPOCH 2 - PROGRESS: at 85.84% examples, 128510 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:48,052 : INFO : EPOCH 2 - PROGRESS: at 87.64% examples, 128764 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:49,073 : INFO : EPOCH 2 - PROGRESS: at 89.53% examples, 128953 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:50,146 : INFO : EPOCH 2 - PROGRESS: at 91.13% examples, 128847 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:51,271 : INFO : EPOCH 2 - PROGRESS: at 92.92% examples, 129018 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:52,333 : INFO : EPOCH 2 - PROGRESS: at 94.72% examples, 129271 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:53,465 : INFO : EPOCH 2 - PROGRESS: at 96.91% examples, 129329 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:54,477 : INFO : EPOCH 2 - PROGRESS: at 98.70% examples, 129308 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:54,971 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-11-20 18:04:55,065 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-20 18:04:55,089 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-20 18:04:55,103 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-20 18:04:55,119 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-20 18:04:55,119 : INFO : EPOCH - 2 : training on 13654253 raw words (8236952 effective words) took 63.6s, 129559 effective words/s
# 2018-11-20 18:04:56,284 : INFO : EPOCH 3 - PROGRESS: at 1.60% examples, 103221 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:57,320 : INFO : EPOCH 3 - PROGRESS: at 3.29% examples, 119287 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:04:58,453 : INFO : EPOCH 3 - PROGRESS: at 4.89% examples, 121920 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:04:59,515 : INFO : EPOCH 3 - PROGRESS: at 6.68% examples, 124164 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:00,549 : INFO : EPOCH 3 - PROGRESS: at 8.28% examples, 125673 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:01,566 : INFO : EPOCH 3 - PROGRESS: at 9.67% examples, 125625 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:02,650 : INFO : EPOCH 3 - PROGRESS: at 10.97% examples, 122141 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:03,696 : INFO : EPOCH 3 - PROGRESS: at 12.16% examples, 120218 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:04,736 : INFO : EPOCH 3 - PROGRESS: at 13.56% examples, 119489 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:05,770 : INFO : EPOCH 3 - PROGRESS: at 15.15% examples, 120512 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:06,829 : INFO : EPOCH 3 - PROGRESS: at 16.65% examples, 120333 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:07,836 : INFO : EPOCH 3 - PROGRESS: at 18.25% examples, 122544 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:08,949 : INFO : EPOCH 3 - PROGRESS: at 19.84% examples, 121714 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:09,944 : INFO : EPOCH 3 - PROGRESS: at 21.73% examples, 123844 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:11,055 : INFO : EPOCH 3 - PROGRESS: at 23.33% examples, 123889 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:12,169 : INFO : EPOCH 3 - PROGRESS: at 25.02% examples, 124351 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:13,209 : INFO : EPOCH 3 - PROGRESS: at 26.92% examples, 124564 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:14,288 : INFO : EPOCH 3 - PROGRESS: at 28.51% examples, 124977 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:15,291 : INFO : EPOCH 3 - PROGRESS: at 30.01% examples, 124655 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:16,291 : INFO : EPOCH 3 - PROGRESS: at 31.31% examples, 123843 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:17,318 : INFO : EPOCH 3 - PROGRESS: at 32.60% examples, 122549 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:18,378 : INFO : EPOCH 3 - PROGRESS: at 34.00% examples, 121526 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:19,401 : INFO : EPOCH 3 - PROGRESS: at 35.59% examples, 122238 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:20,435 : INFO : EPOCH 3 - PROGRESS: at 37.39% examples, 122549 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:21,593 : INFO : EPOCH 3 - PROGRESS: at 38.98% examples, 122708 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:22,601 : INFO : EPOCH 3 - PROGRESS: at 40.68% examples, 123363 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:23,648 : INFO : EPOCH 3 - PROGRESS: at 42.47% examples, 123307 words/s, in_qsize 10, out_qsize 1
# 2018-11-20 18:05:24,667 : INFO : EPOCH 3 - PROGRESS: at 44.47% examples, 123964 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:25,770 : INFO : EPOCH 3 - PROGRESS: at 46.26% examples, 124087 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:26,788 : INFO : EPOCH 3 - PROGRESS: at 47.66% examples, 124251 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:27,887 : INFO : EPOCH 3 - PROGRESS: at 49.25% examples, 124506 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:28,909 : INFO : EPOCH 3 - PROGRESS: at 50.85% examples, 124792 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:29,949 : INFO : EPOCH 3 - PROGRESS: at 52.14% examples, 124469 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:30,976 : INFO : EPOCH 3 - PROGRESS: at 53.64% examples, 124669 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:32,064 : INFO : EPOCH 3 - PROGRESS: at 55.13% examples, 124542 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:33,061 : INFO : EPOCH 3 - PROGRESS: at 56.53% examples, 124137 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:34,088 : INFO : EPOCH 3 - PROGRESS: at 58.23% examples, 124257 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:35,122 : INFO : EPOCH 3 - PROGRESS: at 59.92% examples, 124156 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:36,135 : INFO : EPOCH 3 - PROGRESS: at 61.52% examples, 124479 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:37,178 : INFO : EPOCH 3 - PROGRESS: at 62.91% examples, 124129 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:38,223 : INFO : EPOCH 3 - PROGRESS: at 64.51% examples, 124232 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:39,253 : INFO : EPOCH 3 - PROGRESS: at 66.40% examples, 124421 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:40,291 : INFO : EPOCH 3 - PROGRESS: at 68.49% examples, 125012 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:41,332 : INFO : EPOCH 3 - PROGRESS: at 70.09% examples, 125067 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:42,352 : INFO : EPOCH 3 - PROGRESS: at 71.68% examples, 125212 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:43,354 : INFO : EPOCH 3 - PROGRESS: at 73.18% examples, 125459 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:44,427 : INFO : EPOCH 3 - PROGRESS: at 74.98% examples, 125873 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:45,529 : INFO : EPOCH 3 - PROGRESS: at 76.57% examples, 126084 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:46,632 : INFO : EPOCH 3 - PROGRESS: at 78.17% examples, 126176 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:47,795 : INFO : EPOCH 3 - PROGRESS: at 80.26% examples, 126252 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:48,841 : INFO : EPOCH 3 - PROGRESS: at 82.05% examples, 126691 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:49,900 : INFO : EPOCH 3 - PROGRESS: at 83.35% examples, 126388 words/s, in_qsize 10, out_qsize 1
# 2018-11-20 18:05:50,966 : INFO : EPOCH 3 - PROGRESS: at 84.95% examples, 126452 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:51,989 : INFO : EPOCH 3 - PROGRESS: at 86.44% examples, 126143 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:53,050 : INFO : EPOCH 3 - PROGRESS: at 88.14% examples, 126209 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:54,100 : INFO : EPOCH 3 - PROGRESS: at 89.83% examples, 126094 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:55,101 : INFO : EPOCH 3 - PROGRESS: at 91.43% examples, 126413 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:56,261 : INFO : EPOCH 3 - PROGRESS: at 92.92% examples, 126069 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:05:57,297 : INFO : EPOCH 3 - PROGRESS: at 94.32% examples, 125900 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:58,413 : INFO : EPOCH 3 - PROGRESS: at 95.71% examples, 125501 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:05:59,432 : INFO : EPOCH 3 - PROGRESS: at 97.81% examples, 125528 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:00,417 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-11-20 18:06:00,548 : INFO : EPOCH 3 - PROGRESS: at 99.70% examples, 125475 words/s, in_qsize 3, out_qsize 1
# 2018-11-20 18:06:00,549 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-20 18:06:00,623 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-20 18:06:00,656 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-20 18:06:00,709 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-20 18:06:00,709 : INFO : EPOCH - 3 : training on 13654253 raw words (8237601 effective words) took 65.6s, 125624 effective words/s
# 2018-11-20 18:06:01,851 : INFO : EPOCH 4 - PROGRESS: at 1.60% examples, 104069 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:02,901 : INFO : EPOCH 4 - PROGRESS: at 3.29% examples, 119868 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:03,901 : INFO : EPOCH 4 - PROGRESS: at 4.89% examples, 126397 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:04,918 : INFO : EPOCH 4 - PROGRESS: at 6.68% examples, 128924 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:05,990 : INFO : EPOCH 4 - PROGRESS: at 8.28% examples, 128883 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:06,990 : INFO : EPOCH 4 - PROGRESS: at 9.77% examples, 129335 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:08,134 : INFO : EPOCH 4 - PROGRESS: at 10.97% examples, 123638 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:09,137 : INFO : EPOCH 4 - PROGRESS: at 12.56% examples, 125778 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:10,144 : INFO : EPOCH 4 - PROGRESS: at 14.16% examples, 126219 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:11,185 : INFO : EPOCH 4 - PROGRESS: at 15.75% examples, 127275 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:12,213 : INFO : EPOCH 4 - PROGRESS: at 17.15% examples, 126443 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:13,353 : INFO : EPOCH 4 - PROGRESS: at 18.44% examples, 124185 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:14,376 : INFO : EPOCH 4 - PROGRESS: at 20.34% examples, 125835 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:15,466 : INFO : EPOCH 4 - PROGRESS: at 22.03% examples, 125962 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:16,502 : INFO : EPOCH 4 - PROGRESS: at 23.73% examples, 127286 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:17,564 : INFO : EPOCH 4 - PROGRESS: at 25.52% examples, 128091 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:18,567 : INFO : EPOCH 4 - PROGRESS: at 27.22% examples, 127777 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:19,592 : INFO : EPOCH 4 - PROGRESS: at 28.91% examples, 128609 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:20,688 : INFO : EPOCH 4 - PROGRESS: at 30.71% examples, 129180 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:21,708 : INFO : EPOCH 4 - PROGRESS: at 32.60% examples, 129471 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:22,925 : INFO : EPOCH 4 - PROGRESS: at 34.60% examples, 129379 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:24,005 : INFO : EPOCH 4 - PROGRESS: at 36.59% examples, 130493 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:25,094 : INFO : EPOCH 4 - PROGRESS: at 38.29% examples, 130610 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:26,130 : INFO : EPOCH 4 - PROGRESS: at 39.98% examples, 131239 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:27,146 : INFO : EPOCH 4 - PROGRESS: at 41.97% examples, 131122 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:28,159 : INFO : EPOCH 4 - PROGRESS: at 43.47% examples, 131078 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:29,165 : INFO : EPOCH 4 - PROGRESS: at 45.46% examples, 131752 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:30,214 : INFO : EPOCH 4 - PROGRESS: at 47.06% examples, 131470 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:31,254 : INFO : EPOCH 4 - PROGRESS: at 48.55% examples, 131476 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:32,261 : INFO : EPOCH 4 - PROGRESS: at 50.15% examples, 131605 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:33,344 : INFO : EPOCH 4 - PROGRESS: at 51.55% examples, 131261 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:34,410 : INFO : EPOCH 4 - PROGRESS: at 53.14% examples, 131207 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:35,414 : INFO : EPOCH 4 - PROGRESS: at 54.84% examples, 131615 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:36,464 : INFO : EPOCH 4 - PROGRESS: at 56.53% examples, 131681 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:37,560 : INFO : EPOCH 4 - PROGRESS: at 58.52% examples, 131901 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:38,611 : INFO : EPOCH 4 - PROGRESS: at 60.32% examples, 132035 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:39,786 : INFO : EPOCH 4 - PROGRESS: at 62.11% examples, 132060 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:40,806 : INFO : EPOCH 4 - PROGRESS: at 63.91% examples, 132230 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:41,888 : INFO : EPOCH 4 - PROGRESS: at 65.90% examples, 132298 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:43,098 : INFO : EPOCH 4 - PROGRESS: at 68.10% examples, 132225 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:44,233 : INFO : EPOCH 4 - PROGRESS: at 69.79% examples, 132094 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:45,363 : INFO : EPOCH 4 - PROGRESS: at 71.59% examples, 132313 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:46,562 : INFO : EPOCH 4 - PROGRESS: at 73.18% examples, 131980 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:47,621 : INFO : EPOCH 4 - PROGRESS: at 74.78% examples, 131861 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:48,662 : INFO : EPOCH 4 - PROGRESS: at 76.27% examples, 131984 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:49,673 : INFO : EPOCH 4 - PROGRESS: at 77.77% examples, 132005 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:50,698 : INFO : EPOCH 4 - PROGRESS: at 79.56% examples, 132301 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:51,707 : INFO : EPOCH 4 - PROGRESS: at 81.46% examples, 132408 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:52,804 : INFO : EPOCH 4 - PROGRESS: at 82.85% examples, 131917 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:53,915 : INFO : EPOCH 4 - PROGRESS: at 84.55% examples, 132008 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:54,949 : INFO : EPOCH 4 - PROGRESS: at 86.44% examples, 132201 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:06:56,033 : INFO : EPOCH 4 - PROGRESS: at 88.14% examples, 132147 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:57,061 : INFO : EPOCH 4 - PROGRESS: at 89.83% examples, 131968 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:06:58,118 : INFO : EPOCH 4 - PROGRESS: at 91.13% examples, 131552 words/s, in_qsize 10, out_qsize 1
# 2018-11-20 18:06:59,145 : INFO : EPOCH 4 - PROGRESS: at 92.62% examples, 131494 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:00,189 : INFO : EPOCH 4 - PROGRESS: at 94.12% examples, 131247 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:01,224 : INFO : EPOCH 4 - PROGRESS: at 95.71% examples, 131235 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:02,319 : INFO : EPOCH 4 - PROGRESS: at 98.11% examples, 131385 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:03,079 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-11-20 18:07:03,195 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-20 18:07:03,286 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-20 18:07:03,293 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-20 18:07:03,314 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-20 18:07:03,314 : INFO : EPOCH - 4 : training on 13654253 raw words (8237866 effective words) took 62.6s, 131591 effective words/s
# 2018-11-20 18:07:04,466 : INFO : EPOCH 5 - PROGRESS: at 1.60% examples, 103185 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:05,536 : INFO : EPOCH 5 - PROGRESS: at 3.19% examples, 115157 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:06,556 : INFO : EPOCH 5 - PROGRESS: at 4.69% examples, 118678 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:07,557 : INFO : EPOCH 5 - PROGRESS: at 6.28% examples, 118537 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:08,615 : INFO : EPOCH 5 - PROGRESS: at 7.68% examples, 118300 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:09,614 : INFO : EPOCH 5 - PROGRESS: at 9.17% examples, 120136 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:10,715 : INFO : EPOCH 5 - PROGRESS: at 10.67% examples, 119972 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:11,779 : INFO : EPOCH 5 - PROGRESS: at 12.26% examples, 122640 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:12,890 : INFO : EPOCH 5 - PROGRESS: at 14.06% examples, 123288 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:13,914 : INFO : EPOCH 5 - PROGRESS: at 15.65% examples, 125001 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:15,031 : INFO : EPOCH 5 - PROGRESS: at 17.25% examples, 124862 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:16,247 : INFO : EPOCH 5 - PROGRESS: at 19.14% examples, 125620 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:17,358 : INFO : EPOCH 5 - PROGRESS: at 20.84% examples, 125325 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:18,437 : INFO : EPOCH 5 - PROGRESS: at 22.63% examples, 126338 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:19,438 : INFO : EPOCH 5 - PROGRESS: at 23.83% examples, 125329 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:20,460 : INFO : EPOCH 5 - PROGRESS: at 25.22% examples, 124176 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:21,559 : INFO : EPOCH 5 - PROGRESS: at 27.12% examples, 124513 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:22,634 : INFO : EPOCH 5 - PROGRESS: at 28.71% examples, 124945 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:23,681 : INFO : EPOCH 5 - PROGRESS: at 30.31% examples, 124654 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:24,698 : INFO : EPOCH 5 - PROGRESS: at 32.10% examples, 124871 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:25,886 : INFO : EPOCH 5 - PROGRESS: at 34.00% examples, 125082 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:26,949 : INFO : EPOCH 5 - PROGRESS: at 35.69% examples, 125861 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:27,966 : INFO : EPOCH 5 - PROGRESS: at 37.59% examples, 126590 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:28,996 : INFO : EPOCH 5 - PROGRESS: at 38.98% examples, 126416 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:29,998 : INFO : EPOCH 5 - PROGRESS: at 40.68% examples, 126929 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:31,014 : INFO : EPOCH 5 - PROGRESS: at 42.57% examples, 127245 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:32,119 : INFO : EPOCH 5 - PROGRESS: at 44.67% examples, 127790 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:33,193 : INFO : EPOCH 5 - PROGRESS: at 46.56% examples, 128211 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:34,227 : INFO : EPOCH 5 - PROGRESS: at 48.06% examples, 128293 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:35,244 : INFO : EPOCH 5 - PROGRESS: at 49.45% examples, 128273 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:36,280 : INFO : EPOCH 5 - PROGRESS: at 51.05% examples, 128463 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:37,339 : INFO : EPOCH 5 - PROGRESS: at 52.64% examples, 128707 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:38,343 : INFO : EPOCH 5 - PROGRESS: at 54.34% examples, 129185 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:39,338 : INFO : EPOCH 5 - PROGRESS: at 56.03% examples, 129397 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:40,379 : INFO : EPOCH 5 - PROGRESS: at 57.73% examples, 129745 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:41,387 : INFO : EPOCH 5 - PROGRESS: at 59.72% examples, 130063 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:42,415 : INFO : EPOCH 5 - PROGRESS: at 61.52% examples, 130543 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:43,410 : INFO : EPOCH 5 - PROGRESS: at 63.01% examples, 130259 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:44,473 : INFO : EPOCH 5 - PROGRESS: at 64.61% examples, 130332 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:45,491 : INFO : EPOCH 5 - PROGRESS: at 66.50% examples, 130419 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:46,582 : INFO : EPOCH 5 - PROGRESS: at 68.59% examples, 130550 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:47,629 : INFO : EPOCH 5 - PROGRESS: at 70.29% examples, 130434 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:48,659 : INFO : EPOCH 5 - PROGRESS: at 71.68% examples, 130487 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:49,739 : INFO : EPOCH 5 - PROGRESS: at 73.18% examples, 130355 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:50,743 : INFO : EPOCH 5 - PROGRESS: at 74.68% examples, 130214 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:51,808 : INFO : EPOCH 5 - PROGRESS: at 76.07% examples, 130224 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:52,848 : INFO : EPOCH 5 - PROGRESS: at 77.27% examples, 129648 words/s, in_qsize 10, out_qsize 1
# 2018-11-20 18:07:53,858 : INFO : EPOCH 5 - PROGRESS: at 78.66% examples, 129410 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:54,899 : INFO : EPOCH 5 - PROGRESS: at 80.66% examples, 129605 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:55,964 : INFO : EPOCH 5 - PROGRESS: at 82.15% examples, 129336 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:56,968 : INFO : EPOCH 5 - PROGRESS: at 83.75% examples, 129608 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:07:58,053 : INFO : EPOCH 5 - PROGRESS: at 84.95% examples, 128985 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:07:59,086 : INFO : EPOCH 5 - PROGRESS: at 86.34% examples, 128421 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:00,163 : INFO : EPOCH 5 - PROGRESS: at 88.14% examples, 128590 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:01,204 : INFO : EPOCH 5 - PROGRESS: at 89.83% examples, 128465 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:02,440 : INFO : EPOCH 5 - PROGRESS: at 91.13% examples, 127734 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:03,580 : INFO : EPOCH 5 - PROGRESS: at 92.92% examples, 127873 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:04,628 : INFO : EPOCH 5 - PROGRESS: at 94.62% examples, 128112 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:05,652 : INFO : EPOCH 5 - PROGRESS: at 96.91% examples, 128453 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:06,702 : INFO : EPOCH 5 - PROGRESS: at 98.90% examples, 128597 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:07,037 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-11-20 18:08:07,141 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-20 18:08:07,175 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-20 18:08:07,190 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-20 18:08:07,253 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-20 18:08:07,269 : INFO : EPOCH - 5 : training on 13654253 raw words (8237815 effective words) took 64.0s, 128816 effective words/s
# 2018-11-20 18:08:07,269 : INFO : training on a 68271265 raw words (41188282 effective words) took 314.9s, 130782 effective words/s
# 2018-11-20 18:08:07,269 : INFO : Training iteration #1
# 2018-11-20 18:08:07,269 : WARNING : Effective 'alpha' higher than previous training cycles
# 2018-11-20 18:08:07,269 : INFO : training model with 5 workers on 511920 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=10
# 2018-11-20 18:08:08,299 : INFO : EPOCH 1 - PROGRESS: at 1.79% examples, 121572 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:09,335 : INFO : EPOCH 1 - PROGRESS: at 3.39% examples, 125258 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:10,430 : INFO : EPOCH 1 - PROGRESS: at 5.18% examples, 131574 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:11,490 : INFO : EPOCH 1 - PROGRESS: at 6.88% examples, 132038 words/s, in_qsize 10, out_qsize 1
# 2018-11-20 18:08:12,517 : INFO : EPOCH 1 - PROGRESS: at 8.87% examples, 134074 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:13,592 : INFO : EPOCH 1 - PROGRESS: at 10.57% examples, 133110 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:14,767 : INFO : EPOCH 1 - PROGRESS: at 12.26% examples, 130908 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:15,804 : INFO : EPOCH 1 - PROGRESS: at 14.16% examples, 131689 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:16,789 : INFO : EPOCH 1 - PROGRESS: at 16.35% examples, 132043 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:17,882 : INFO : EPOCH 1 - PROGRESS: at 18.34% examples, 132207 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:18,892 : INFO : EPOCH 1 - PROGRESS: at 20.04% examples, 132382 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:20,029 : INFO : EPOCH 1 - PROGRESS: at 21.44% examples, 130359 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:21,054 : INFO : EPOCH 1 - PROGRESS: at 23.03% examples, 130179 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:22,097 : INFO : EPOCH 1 - PROGRESS: at 24.53% examples, 130348 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:23,139 : INFO : EPOCH 1 - PROGRESS: at 25.92% examples, 129796 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:24,177 : INFO : EPOCH 1 - PROGRESS: at 27.92% examples, 130464 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:25,245 : INFO : EPOCH 1 - PROGRESS: at 29.81% examples, 130277 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:26,249 : INFO : EPOCH 1 - PROGRESS: at 31.31% examples, 130804 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:27,259 : INFO : EPOCH 1 - PROGRESS: at 32.20% examples, 128002 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:28,407 : INFO : EPOCH 1 - PROGRESS: at 33.80% examples, 127326 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:29,457 : INFO : EPOCH 1 - PROGRESS: at 35.29% examples, 127660 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:30,530 : INFO : EPOCH 1 - PROGRESS: at 36.49% examples, 126275 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:31,537 : INFO : EPOCH 1 - PROGRESS: at 37.69% examples, 125352 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:32,643 : INFO : EPOCH 1 - PROGRESS: at 38.98% examples, 124201 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:33,645 : INFO : EPOCH 1 - PROGRESS: at 40.38% examples, 123558 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:34,721 : INFO : EPOCH 1 - PROGRESS: at 41.67% examples, 123327 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:35,849 : INFO : EPOCH 1 - PROGRESS: at 43.47% examples, 123883 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:36,884 : INFO : EPOCH 1 - PROGRESS: at 45.26% examples, 124202 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:37,935 : INFO : EPOCH 1 - PROGRESS: at 46.76% examples, 124825 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:38,949 : INFO : EPOCH 1 - PROGRESS: at 48.45% examples, 125254 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:40,182 : INFO : EPOCH 1 - PROGRESS: at 49.95% examples, 124480 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:41,255 : INFO : EPOCH 1 - PROGRESS: at 51.55% examples, 124638 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:42,263 : INFO : EPOCH 1 - PROGRESS: at 53.24% examples, 125189 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:43,280 : INFO : EPOCH 1 - PROGRESS: at 54.94% examples, 125542 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:44,294 : INFO : EPOCH 1 - PROGRESS: at 56.63% examples, 125823 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:45,310 : INFO : EPOCH 1 - PROGRESS: at 58.13% examples, 125795 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:46,391 : INFO : EPOCH 1 - PROGRESS: at 59.82% examples, 126240 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:47,453 : INFO : EPOCH 1 - PROGRESS: at 61.71% examples, 126399 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:48,504 : INFO : EPOCH 1 - PROGRESS: at 63.51% examples, 126777 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:49,538 : INFO : EPOCH 1 - PROGRESS: at 65.10% examples, 127014 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:50,582 : INFO : EPOCH 1 - PROGRESS: at 66.90% examples, 127280 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:51,679 : INFO : EPOCH 1 - PROGRESS: at 68.49% examples, 127275 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:08:52,690 : INFO : EPOCH 1 - PROGRESS: at 70.19% examples, 127552 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:53,743 : INFO : EPOCH 1 - PROGRESS: at 72.08% examples, 127674 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:54,870 : INFO : EPOCH 1 - PROGRESS: at 73.88% examples, 127518 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:55,931 : INFO : EPOCH 1 - PROGRESS: at 75.47% examples, 127621 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:57,034 : INFO : EPOCH 1 - PROGRESS: at 77.27% examples, 127355 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:58,047 : INFO : EPOCH 1 - PROGRESS: at 78.76% examples, 127230 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:08:59,041 : INFO : EPOCH 1 - PROGRESS: at 80.56% examples, 127439 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:00,119 : INFO : EPOCH 1 - PROGRESS: at 82.05% examples, 127366 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:01,244 : INFO : EPOCH 1 - PROGRESS: at 84.05% examples, 127209 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:02,258 : INFO : EPOCH 1 - PROGRESS: at 85.84% examples, 127233 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:03,405 : INFO : EPOCH 1 - PROGRESS: at 87.64% examples, 127148 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:04,521 : INFO : EPOCH 1 - PROGRESS: at 89.03% examples, 126907 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:05,544 : INFO : EPOCH 1 - PROGRESS: at 90.63% examples, 127062 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:06,602 : INFO : EPOCH 1 - PROGRESS: at 92.12% examples, 127147 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:07,632 : INFO : EPOCH 1 - PROGRESS: at 93.92% examples, 127514 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:08,674 : INFO : EPOCH 1 - PROGRESS: at 95.31% examples, 127521 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:09,731 : INFO : EPOCH 1 - PROGRESS: at 96.71% examples, 127275 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:10,792 : INFO : EPOCH 1 - PROGRESS: at 98.40% examples, 127485 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:11,522 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-11-20 18:09:11,590 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-20 18:09:11,605 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-20 18:09:11,621 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-20 18:09:11,637 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-20 18:09:11,652 : INFO : EPOCH - 1 : training on 13654253 raw words (8237910 effective words) took 64.4s, 127971 effective words/s
# 2018-11-20 18:09:12,672 : INFO : EPOCH 2 - PROGRESS: at 1.69% examples, 115550 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:13,708 : INFO : EPOCH 2 - PROGRESS: at 3.19% examples, 117922 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:14,746 : INFO : EPOCH 2 - PROGRESS: at 4.69% examples, 122233 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:15,754 : INFO : EPOCH 2 - PROGRESS: at 6.18% examples, 122232 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:16,815 : INFO : EPOCH 2 - PROGRESS: at 8.08% examples, 122885 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:17,851 : INFO : EPOCH 2 - PROGRESS: at 9.47% examples, 120566 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:19,006 : INFO : EPOCH 2 - PROGRESS: at 10.97% examples, 119495 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:20,033 : INFO : EPOCH 2 - PROGRESS: at 12.86% examples, 122313 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:21,039 : INFO : EPOCH 2 - PROGRESS: at 14.76% examples, 123543 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:22,143 : INFO : EPOCH 2 - PROGRESS: at 16.95% examples, 124620 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:23,294 : INFO : EPOCH 2 - PROGRESS: at 19.14% examples, 125921 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:24,374 : INFO : EPOCH 2 - PROGRESS: at 20.84% examples, 126453 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:25,458 : INFO : EPOCH 2 - PROGRESS: at 22.63% examples, 127437 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:26,535 : INFO : EPOCH 2 - PROGRESS: at 24.23% examples, 127791 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:27,610 : INFO : EPOCH 2 - PROGRESS: at 25.92% examples, 128916 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:28,654 : INFO : EPOCH 2 - PROGRESS: at 27.92% examples, 129687 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:09:29,704 : INFO : EPOCH 2 - PROGRESS: at 29.81% examples, 129681 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:09:30,830 : INFO : EPOCH 2 - PROGRESS: at 31.41% examples, 129925 words/s, in_qsize 9, out_qsize 0
# ...
# 2018-11-20 18:51:10,918 : INFO : EPOCH 3 - PROGRESS: at 82.45% examples, 144933 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:11,938 : INFO : EPOCH 3 - PROGRESS: at 84.45% examples, 145117 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:12,989 : INFO : EPOCH 3 - PROGRESS: at 86.24% examples, 144965 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:14,038 : INFO : EPOCH 3 - PROGRESS: at 88.04% examples, 145111 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:15,115 : INFO : EPOCH 3 - PROGRESS: at 89.73% examples, 144902 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:16,126 : INFO : EPOCH 3 - PROGRESS: at 91.63% examples, 145036 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:17,153 : INFO : EPOCH 3 - PROGRESS: at 93.62% examples, 144963 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:18,159 : INFO : EPOCH 3 - PROGRESS: at 95.51% examples, 145237 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:19,155 : INFO : EPOCH 3 - PROGRESS: at 97.51% examples, 145227 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:20,182 : INFO : EPOCH 3 - PROGRESS: at 99.30% examples, 145031 words/s, in_qsize 7, out_qsize 0
# 2018-11-20 18:51:20,343 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-11-20 18:51:20,375 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-20 18:51:20,468 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-20 18:51:20,468 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-20 18:51:20,562 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-20 18:51:20,562 : INFO : EPOCH - 3 : training on 13654253 raw words (8238010 effective words) took 56.7s, 145258 effective words/s
# 2018-11-20 18:51:21,612 : INFO : EPOCH 4 - PROGRESS: at 1.60% examples, 135153 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:22,709 : INFO : EPOCH 4 - PROGRESS: at 3.39% examples, 137150 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:23,760 : INFO : EPOCH 4 - PROGRESS: at 5.38% examples, 137767 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:24,779 : INFO : EPOCH 4 - PROGRESS: at 7.08% examples, 142183 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:25,785 : INFO : EPOCH 4 - PROGRESS: at 8.77% examples, 142573 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:26,786 : INFO : EPOCH 4 - PROGRESS: at 10.47% examples, 141857 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:27,822 : INFO : EPOCH 4 - PROGRESS: at 12.06% examples, 143174 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:28,843 : INFO : EPOCH 4 - PROGRESS: at 13.76% examples, 144219 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:29,861 : INFO : EPOCH 4 - PROGRESS: at 15.45% examples, 143712 words/s, in_qsize 8, out_qsize 1
# 2018-11-20 18:51:30,862 : INFO : EPOCH 4 - PROGRESS: at 17.15% examples, 144328 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:31,865 : INFO : EPOCH 4 - PROGRESS: at 19.04% examples, 145245 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:32,947 : INFO : EPOCH 4 - PROGRESS: at 21.04% examples, 144963 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:34,013 : INFO : EPOCH 4 - PROGRESS: at 23.13% examples, 145059 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:35,032 : INFO : EPOCH 4 - PROGRESS: at 24.83% examples, 144850 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:36,083 : INFO : EPOCH 4 - PROGRESS: at 26.82% examples, 145422 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:37,207 : INFO : EPOCH 4 - PROGRESS: at 28.71% examples, 145075 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:38,289 : INFO : EPOCH 4 - PROGRESS: at 31.01% examples, 145445 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:39,424 : INFO : EPOCH 4 - PROGRESS: at 33.20% examples, 145226 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:40,493 : INFO : EPOCH 4 - PROGRESS: at 35.19% examples, 145418 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:41,588 : INFO : EPOCH 4 - PROGRESS: at 36.99% examples, 145476 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:42,639 : INFO : EPOCH 4 - PROGRESS: at 38.88% examples, 145545 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:43,673 : INFO : EPOCH 4 - PROGRESS: at 40.68% examples, 145392 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:44,725 : INFO : EPOCH 4 - PROGRESS: at 42.67% examples, 145902 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:45,851 : INFO : EPOCH 4 - PROGRESS: at 44.47% examples, 145409 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:46,899 : INFO : EPOCH 4 - PROGRESS: at 46.36% examples, 145610 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:47,923 : INFO : EPOCH 4 - PROGRESS: at 48.06% examples, 145515 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:48,957 : INFO : EPOCH 4 - PROGRESS: at 49.95% examples, 145635 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:50,055 : INFO : EPOCH 4 - PROGRESS: at 52.04% examples, 145510 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:51,060 : INFO : EPOCH 4 - PROGRESS: at 53.74% examples, 145659 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:52,057 : INFO : EPOCH 4 - PROGRESS: at 55.53% examples, 145691 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:53,080 : INFO : EPOCH 4 - PROGRESS: at 57.73% examples, 145839 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:54,110 : INFO : EPOCH 4 - PROGRESS: at 59.32% examples, 145809 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:55,184 : INFO : EPOCH 4 - PROGRESS: at 61.12% examples, 145779 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:56,326 : INFO : EPOCH 4 - PROGRESS: at 63.11% examples, 145728 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:57,339 : INFO : EPOCH 4 - PROGRESS: at 65.10% examples, 146084 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:51:58,418 : INFO : EPOCH 4 - PROGRESS: at 67.10% examples, 145932 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:51:59,557 : INFO : EPOCH 4 - PROGRESS: at 68.99% examples, 145798 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:00,595 : INFO : EPOCH 4 - PROGRESS: at 70.79% examples, 146000 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:01,606 : INFO : EPOCH 4 - PROGRESS: at 72.48% examples, 145966 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:02,718 : INFO : EPOCH 4 - PROGRESS: at 74.28% examples, 145784 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:03,713 : INFO : EPOCH 4 - PROGRESS: at 76.37% examples, 146272 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:04,792 : INFO : EPOCH 4 - PROGRESS: at 78.07% examples, 145911 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:05,813 : INFO : EPOCH 4 - PROGRESS: at 79.86% examples, 146045 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:06,832 : INFO : EPOCH 4 - PROGRESS: at 81.56% examples, 145939 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:07,961 : INFO : EPOCH 4 - PROGRESS: at 83.65% examples, 146084 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:08,965 : INFO : EPOCH 4 - PROGRESS: at 85.64% examples, 146096 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:09,970 : INFO : EPOCH 4 - PROGRESS: at 87.34% examples, 146136 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:10,970 : INFO : EPOCH 4 - PROGRESS: at 89.13% examples, 146220 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:12,038 : INFO : EPOCH 4 - PROGRESS: at 90.73% examples, 145967 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:13,214 : INFO : EPOCH 4 - PROGRESS: at 93.02% examples, 145900 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:14,244 : INFO : EPOCH 4 - PROGRESS: at 95.11% examples, 146199 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:15,389 : INFO : EPOCH 4 - PROGRESS: at 97.21% examples, 145989 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:16,471 : INFO : EPOCH 4 - PROGRESS: at 99.30% examples, 146131 words/s, in_qsize 7, out_qsize 0
# 2018-11-20 18:52:16,663 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-11-20 18:52:16,679 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-20 18:52:16,757 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-20 18:52:16,788 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-20 18:52:16,913 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-20 18:52:16,913 : INFO : EPOCH - 4 : training on 13654253 raw words (8238068 effective words) took 56.3s, 146197 effective words/s
# 2018-11-20 18:52:17,991 : INFO : EPOCH 5 - PROGRESS: at 1.50% examples, 124497 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:19,031 : INFO : EPOCH 5 - PROGRESS: at 3.39% examples, 138783 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:20,065 : INFO : EPOCH 5 - PROGRESS: at 5.38% examples, 140429 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:21,161 : INFO : EPOCH 5 - PROGRESS: at 7.08% examples, 141434 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:22,208 : INFO : EPOCH 5 - PROGRESS: at 9.17% examples, 146016 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:23,275 : INFO : EPOCH 5 - PROGRESS: at 10.87% examples, 145366 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:24,330 : INFO : EPOCH 5 - PROGRESS: at 12.36% examples, 144135 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:25,472 : INFO : EPOCH 5 - PROGRESS: at 14.26% examples, 144143 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:26,568 : INFO : EPOCH 5 - PROGRESS: at 16.15% examples, 144799 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:27,583 : INFO : EPOCH 5 - PROGRESS: at 17.75% examples, 144577 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:28,593 : INFO : EPOCH 5 - PROGRESS: at 19.54% examples, 145005 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:29,677 : INFO : EPOCH 5 - PROGRESS: at 21.64% examples, 144456 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:30,712 : INFO : EPOCH 5 - PROGRESS: at 23.63% examples, 144239 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:31,826 : INFO : EPOCH 5 - PROGRESS: at 25.42% examples, 144001 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:32,939 : INFO : EPOCH 5 - PROGRESS: at 27.62% examples, 144436 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:33,957 : INFO : EPOCH 5 - PROGRESS: at 29.41% examples, 144490 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:35,073 : INFO : EPOCH 5 - PROGRESS: at 31.80% examples, 144756 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:36,154 : INFO : EPOCH 5 - PROGRESS: at 34.00% examples, 145034 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:37,172 : INFO : EPOCH 5 - PROGRESS: at 35.69% examples, 145175 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:38,190 : INFO : EPOCH 5 - PROGRESS: at 37.29% examples, 144935 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:39,209 : INFO : EPOCH 5 - PROGRESS: at 39.28% examples, 144958 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:40,227 : INFO : EPOCH 5 - PROGRESS: at 41.08% examples, 145607 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:41,294 : INFO : EPOCH 5 - PROGRESS: at 42.77% examples, 145096 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:42,289 : INFO : EPOCH 5 - PROGRESS: at 44.57% examples, 145292 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:43,451 : INFO : EPOCH 5 - PROGRESS: at 46.56% examples, 145230 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:44,586 : INFO : EPOCH 5 - PROGRESS: at 48.65% examples, 145481 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:45,575 : INFO : EPOCH 5 - PROGRESS: at 50.45% examples, 145450 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:46,606 : INFO : EPOCH 5 - PROGRESS: at 52.44% examples, 145536 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:47,662 : INFO : EPOCH 5 - PROGRESS: at 54.04% examples, 145384 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:48,753 : INFO : EPOCH 5 - PROGRESS: at 56.13% examples, 145609 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:49,780 : INFO : EPOCH 5 - PROGRESS: at 58.23% examples, 145756 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:50,797 : INFO : EPOCH 5 - PROGRESS: at 59.82% examples, 145690 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:51,911 : INFO : EPOCH 5 - PROGRESS: at 61.71% examples, 145582 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:52,921 : INFO : EPOCH 5 - PROGRESS: at 63.61% examples, 145804 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:53,938 : INFO : EPOCH 5 - PROGRESS: at 65.30% examples, 145648 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:54,969 : INFO : EPOCH 5 - PROGRESS: at 67.20% examples, 145435 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:56,066 : INFO : EPOCH 5 - PROGRESS: at 69.09% examples, 145532 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:52:57,167 : INFO : EPOCH 5 - PROGRESS: at 70.99% examples, 145683 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:58,289 : INFO : EPOCH 5 - PROGRESS: at 72.78% examples, 145525 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:52:59,304 : INFO : EPOCH 5 - PROGRESS: at 74.68% examples, 145834 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:53:00,376 : INFO : EPOCH 5 - PROGRESS: at 76.57% examples, 145703 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:53:01,390 : INFO : EPOCH 5 - PROGRESS: at 78.56% examples, 146140 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:53:02,464 : INFO : EPOCH 5 - PROGRESS: at 80.36% examples, 145863 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:53:03,490 : INFO : EPOCH 5 - PROGRESS: at 82.15% examples, 145861 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:53:04,537 : INFO : EPOCH 5 - PROGRESS: at 83.95% examples, 145865 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:53:05,584 : INFO : EPOCH 5 - PROGRESS: at 85.94% examples, 145890 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:53:06,651 : INFO : EPOCH 5 - PROGRESS: at 87.74% examples, 145836 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:53:07,685 : INFO : EPOCH 5 - PROGRESS: at 89.53% examples, 145952 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:53:08,752 : INFO : EPOCH 5 - PROGRESS: at 91.43% examples, 145979 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:53:09,834 : INFO : EPOCH 5 - PROGRESS: at 93.62% examples, 146007 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:53:10,885 : INFO : EPOCH 5 - PROGRESS: at 95.51% examples, 146138 words/s, in_qsize 10, out_qsize 0
# 2018-11-20 18:53:11,902 : INFO : EPOCH 5 - PROGRESS: at 97.61% examples, 146276 words/s, in_qsize 9, out_qsize 0
# 2018-11-20 18:53:12,954 : INFO : EPOCH 5 - PROGRESS: at 99.40% examples, 145978 words/s, in_qsize 6, out_qsize 0
# 2018-11-20 18:53:13,028 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-11-20 18:53:13,028 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-20 18:53:13,178 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-20 18:53:13,203 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-20 18:53:13,237 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-20 18:53:13,237 : INFO : EPOCH - 5 : training on 13654253 raw words (8237712 effective words) took 56.3s, 146276 effective words/s
# 2018-11-20 18:53:13,237 : INFO : training on a 68271265 raw words (41190077 effective words) took 282.7s, 145718 effective words/s
# 2018-11-20 18:53:13,237 : INFO : Saving trained Doc2Vec model
# 2018-11-20 18:53:13,237 : INFO : saving Doc2Vec object under d2v.model, separately None
# 2018-11-20 18:53:13,237 : INFO : storing np array 'syn1neg' to d2v.model.trainables.syn1neg.npy
# 2018-11-20 18:53:13,751 : INFO : storing np array 'vectors' to d2v.model.wv.vectors.npy
# 2018-11-20 18:53:15,511 : INFO : saved d2v.model
# 2018-11-20 18:53:15,965 : INFO : Classifier training
# 2018-11-20 18:53:16,126 : INFO : Training predicted classes: ['failure' 'success']
# 2018-11-20 18:53:16,128 : INFO : Training accuracy: 0.8945868945868946
# 2018-11-20 18:53:16,133 : INFO : Training F1 score: 0.8936859278739621
# 2018-11-20 18:53:16,134 : INFO : Classifier testing
# 2018-11-20 18:53:16,138 : INFO : Testing predicted classes: ['failure' 'success']
# 2018-11-20 18:53:16,140 : INFO : Testing accuracy: 0.627906976744186
# 2018-11-20 18:53:16,142 : INFO : Testing F1 score: 0.6300587759981404
